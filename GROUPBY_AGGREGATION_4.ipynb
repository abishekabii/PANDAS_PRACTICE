# %%
import pandas as pd
df=pd.read_csv("FILES/Flavors.csv")
df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %% [markdown]
# Groupu by Method

# %%
df.groupby('Base Flavor')

# %% [markdown]
# Use some variable

# %%
grouped_by_frame =df.groupby('Base Flavor')
grouped_by_frame

# %% [markdown]
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000020D58536EA0>
#
# The above error indicating that indicates that df.groupby('Base Flavor') returns a GroupBy object, not the actual grouped data.
#
# After grouping, We need to apply an aggregation function like .mean(), .sum(), .count(), etc., to see the results.

# %%
grouped_by_frame.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...

# %%
grouped_by_frame.mean(numeric_only=True)
# Out:
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate              8.4        7.233333         15.70
# Vanilla                5.7        5.650000         11.35

# %%
df.groupby('Base Flavor').mean(numeric_only=True)
# Out:
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate              8.4        7.233333         15.70
# Vanilla                5.7        5.650000         11.35

# %%
df.groupby('Base Flavor').count()
# Out:
#              Flavor  Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate         3      3              3               3             3
# Vanilla           6      6              6               6             6

# %%
df.groupby('Base Flavor').min()
# Out:
#                   Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate      Chocolate   Yes            8.2             7.0          15.2
# Vanilla      Cake Batter    No            2.3             3.4           5.7

# %%
df.groupby('Base Flavor').max()
# Out:
#                  Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate    Rocky Road   Yes            8.8             7.6          16.6
# Vanilla         Vanilla   Yes           10.0             8.0          18.0

# %%
df.groupby('Base Flavor').sum()
# Out:
#                                                         Flavor  \
# Base Flavor
# Chocolate            ChocolateRocky RoadChocolte Fudge Brownie
# Vanilla      Mint Chocolate ChipVanillaCookie DoughPistachi...
#
#                        Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate          YesYesYes           25.2            21.7          47.1
# Vanilla      YesNoYesNoYesNo           34.2            33.9          68.1

# %%
df.groupby('Base Flavor').sum(numeric_only=True)
# Out:
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate             25.2            21.7          47.1
# Vanilla               34.2            33.9          68.1

# %% [markdown]
# Aggregation using agg function
#
# Here we need to pass as a dictionary
#
# {'<Column_name>':'<Aggregate_Function>'}
#
# Can also be the list
#
# {'<Column_name>':'[<Aggregate_Function>,<Aggregate_Function>,<Aggregate_Function>]'}

# %%
df.groupby('Base Flavor').agg({'Flavor Rating':'max'})
# Out:
#              Flavor Rating
# Base Flavor
# Chocolate              8.8
# Vanilla               10.0

# %%
df.groupby('Base Flavor').agg({'Flavor Rating':['max','min','sum','mean','count']})
# Out:
#             Flavor Rating
#                       max  min   sum mean count
# Base Flavor
# Chocolate             8.8  8.2  25.2  8.4     3
# Vanilla              10.0  2.3  34.2  5.7     6

# %%
df.groupby('Base Flavor').agg({'Flavor Rating':['max','min','sum','mean','count'],
                               'Texture Rating':['max','min','sum','mean','count']})
# Out:
#             Flavor Rating                       Texture Rating             \
#                       max  min   sum mean count            max  min   sum
# Base Flavor
# Chocolate             8.8  8.2  25.2  8.4     3            7.6  7.0  21.7
# Vanilla              10.0  2.3  34.2  5.7     6            8.0  3.4  33.9
#
#
#                  mean count
# Base Flavor
# Chocolate    7.233333     3
# Vanilla      5.650000     6

# %% [markdown]
# Till now we grouped one column we can also group multiple columns

# %%
df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
df.groupby(['Base Flavor','Liked']).min(numeric_only=True)
# Out:
#                    Flavor Rating  Texture Rating  Total Rating
# Base Flavor Liked
# Chocolate   Yes              8.2             7.0          15.2
# Vanilla     No               2.3             3.4           5.7
#             Yes              6.5             6.0          12.5

# %%
df.groupby(['Base Flavor','Liked']).agg({'Flavor Rating':['max','min','sum','mean','count'],
                               'Texture Rating':['max','min','sum','mean','count']})
# Out:
#                   Flavor Rating                       Texture Rating       \
#                             max  min   sum mean count            max  min
# Base Flavor Liked
# Chocolate   Yes             8.8  8.2  25.2  8.4     3            7.6  7.0
# Vanilla     No              4.7  2.3  10.8  3.6     3            5.0  3.4
#             Yes            10.0  6.5  23.4  7.8     3            8.0  6.0
#
#
#                     sum      mean count
# Base Flavor Liked
# Chocolate   Yes    21.7  7.233333     3
# Vanilla     No     13.4  4.466667     3
#             Yes    20.5  6.833333     3

# %% [markdown]
# We can use Describe function to get overall view

# %%
df.groupby(['Base Flavor','Liked']).describe()
# Out:
#                   Flavor Rating                                             \
#                           count mean       std  min   25%  50%   75%   max
# Base Flavor Liked
# Chocolate   Yes             3.0  8.4  0.346410  8.2  8.20  8.2  8.50   8.8
# Vanilla     No              3.0  3.6  1.212436  2.3  3.05  3.8  4.25   4.7
#             Yes             3.0  7.8  1.915724  6.5  6.70  6.9  8.45  10.0
#
#                   Texture Rating            ...            Total Rating  \
#                            count      mean  ...   75%  max        count
# Base Flavor Liked                           ...
# Chocolate   Yes              3.0  7.233333  ...  7.35  7.6          3.0
# Vanilla     No               3.0  4.466667  ...  5.00  5.0          3.0
#             Yes              3.0  6.833333  ...  7.25  8.0          3.0
#
#
#                         mean       std   min    25%   50%    75%   max
# Base Flavor Liked
# ...
