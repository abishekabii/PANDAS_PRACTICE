# %% [markdown]
# <h2>DATA CLEANING</h2>

# %% [markdown]
# Data cleaning, also known as data cleansing or data scrubbing, is the process of identifying and correcting (or removing) errors, inconsistencies, and inaccuracies within a dataset.
#
# This crucial step in the data management and data science pipeline ensures that the data is accurate, consistent, and reliable, which is essential for effective analysis and decision-making.

# %% [markdown]
# Inaccurate data: Fixing or removing incorrect values.
#
# Inconsistent data: Standardizing formats (e.g., dates, capitalization).
#
# Duplicate data: Removing redundant entries.
#
# Missing data: Addressing missing values (e.g., imputation or removal).
#
# Outliers: Identifying and handling extreme values.
#
# Irrelevant data: Removing data that doesn't contribute to the analysis.
#
# Typographical errors: Correcting spelling mistakes and typos.
#
# Corrupted data: Fixing or removing damaged data.

# %% [markdown]
# There are many ways to clean the data

# %%
import pandas as pd
df=pd.read_excel("FILES/Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# To drop / delete the duplicates

# %%
df.drop_duplicates()
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# To save the dropped duplicates

# %%
df=df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# To drop / delete the unrelevant or not important columns

# %%
df=df.drop(columns="Not_Useful_Column")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# To remove / drop the typo error or want to remove some characters from the column
#
# Using strip method

# %%
df['Last_Name']=df['Last_Name'].str.strip() 
df['Last_Name']
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %% [markdown]
# It's not removed because in strip we not mention any character

# %%
df['Last_Name']=df['Last_Name'].str.lstrip("/") 
df['Last_Name']
# Out:
# 0         Baggins
# 1           Nadir
# 2           White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %% [markdown]
# Now it's removed the character from column starts with "/"

# %%
df['Last_Name']=df['Last_Name'].str.rstrip("_") 
df['Last_Name']
# Out:
# 0        Baggins
# 1          Nadir
# 2          White
# 3        Schrute
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8            NaN
# 9         Parker
# 10        Gamgee
# 11     ...Potter
# 12        Draper
# 13         Knope
# 14    Flenderson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# Name: Last_Name, dtype: object

# %% [markdown]
# Now it's removed the character from column ends with "_"

# %%
df['Last_Name']=df['Last_Name'].str.lstrip("/")
df['Last_Name']=df['Last_Name'].str.lstrip("...")
df['Last_Name']=df['Last_Name'].str.rstrip("_")  
df['Last_Name']
# Out:
# 0        Baggins
# 1          Nadir
# 2          White
# 3        Schrute
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8            NaN
# 9         Parker
# 10        Gamgee
# 11        Potter
# 12        Draper
# 13         Knope
# 14    Flenderson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# Name: Last_Name, dtype: object

# %% [markdown]
# We can also mention every thing in one string

# %%
df['Last_Name'].str.strip("123._/")
# Out:
# 0        Baggins
# 1          Nadir
# 2          White
# 3        Schrute
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8            NaN
# 9         Parker
# 10        Gamgee
# 11        Potter
# 12        Draper
# 13         Knope
# 14    Flenderson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# Name: Last_Name, dtype: object

# %% [markdown]
# To save the changes

# %%
df['Last_Name']=df['Last_Name'].str.strip("123._/")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %% [markdown]
# Now to clean phone number we have many formats but we have to keep exactly one format and follow that one

# %% [markdown]
# Replace invalid values like "N/a" and "NaN" with None (NaN in Pandas).

# %%
df["Phone_Number"].replace(["N/a", "NaN", "n/a"], None)
# Out:
# 0     123-545-5421
# 1     123/643/9775
# 2       7066950392
# 3     123-543-2345
# 4     876|678|3469
# 5     304-762-2467
# 6              NaN
# 7     876|678|3469
# 8             None
# 9     123-545-5421
# 10             NaN
# 11      7066950392
# 12    123-543-2345
# 13    876|678|3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123/643/9775
# 17      7066950392
# 18            None
# 19    876|678|3469
# Name: Phone_Number, dtype: object

# %% [markdown]
# Here in phone_number column we have both string and number so we want to standardize in to one type

# %% [markdown]
# Using Lambda function for this

# %%
df['Phone_Number'].apply(lambda x:str(x))
# Out:
# 0     123-545-5421
# 1     123/643/9775
# 2       7066950392
# 3     123-543-2345
# 4     876|678|3469
# 5     304-762-2467
# 6              nan
# 7     876|678|3469
# 8              N/a
# 9     123-545-5421
# 10             nan
# 11      7066950392
# 12    123-543-2345
# 13    876|678|3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123/643/9775
# 17      7066950392
# 18             N/a
# 19    876|678|3469
# Name: Phone_Number, dtype: object

# %%
df['Phone_Number']=df["Phone_Number"].apply(lambda x:str(x)).replace(["N/a", "NaN", "n/a","nan"], 'None')
df['Phone_Number']
# Out:
# 0     123-545-5421
# 1     123/643/9775
# 2       7066950392
# 3     123-543-2345
# 4     876|678|3469
# 5     304-762-2467
# 6             None
# 7     876|678|3469
# 8             None
# 9     123-545-5421
# 10            None
# 11      7066950392
# 12    123-543-2345
# 13    876|678|3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123/643/9775
# 17      7066950392
# 18            None
# 19    876|678|3469
# Name: Phone_Number, dtype: object

# %% [markdown]
# We will remove all non-numeric characters (like -, /, |)
#
# Using regular expression

# %%
df['Phone_Number'] = df["Phone_Number"].str.replace(r'\D', '', regex=True)
df['Phone_Number']
# Out:
# 0     1235455421
# 1     1236439775
# 2     7066950392
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6
# 7     8766783469
# 8
# 9     1235455421
# 10
# 11    7066950392
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17    7066950392
# 18
# 19    8766783469
# Name: Phone_Number, dtype: object

# %% [markdown]
# Set non-10-digit numbers to None.

# %%
df["Phone_Number"] = df["Phone_Number"].apply(lambda x: x if pd.notna(x) and len(x) == 10 else None)
df['Phone_Number']
# Out:
# 0     1235455421
# 1     1236439775
# 2     7066950392
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6           None
# 7     8766783469
# 8           None
# 9     1235455421
# 10          None
# 11    7066950392
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17    7066950392
# 18          None
# 19    8766783469
# Name: Phone_Number, dtype: object

# %% [markdown]
# Format valid phone numbers using slicing

# %%
df["Phone_Number"] = df["Phone_Number"].apply(lambda x: f"{x[:3]}-{x[3:6]}-{x[6:]}" if pd.notna(x) else None)
df['Phone_Number']
# Out:
# 0     123-545-5421
# 1     123-643-9775
# 2     706-695-0392
# 3     123-543-2345
# 4     876-678-3469
# 5     304-762-2467
# 6             None
# 7     876-678-3469
# 8             None
# 9     123-545-5421
# 10            None
# 11    706-695-0392
# 12    123-543-2345
# 13    876-678-3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123-643-9775
# 17    706-695-0392
# 18            None
# 19    876-678-3469
# Name: Phone_Number, dtype: object

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger          None
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN          None
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee          None
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# ...

# %% [markdown]
# We can define and use that function also

# %%
import pandas as pd
df2=pd.read_excel("FILES/Customer Call List.xlsx")
df2
import re

def clean_phone_number(phone):
    if pd.isna(phone) or phone in ["N/a", "NaN", "n/a"]:
        return None  # Return None for missing values
    
    # Remove all non-numeric characters
    phone = re.sub(r'\D', '', phone)

    # Ensure the number has exactly 10 digits
    if len(phone) == 10:
        return f"{phone[:3]}-{phone[3:6]}-{phone[6:]}"  # Format as XXX-XXX-XXXX
    else:
        return None  # Invalid numbers are set to None

# Apply the function to clean the Phone_Number column
df2['Phone_Number']=df2['Phone_Number'].apply(lambda x:str(x))
df2['Phone_Number'] = df2['Phone_Number'].apply(clean_phone_number)

df2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 import pandas as pd
# ----> 2 df2=pd.read_excel("C:\\Users\\admin\\OneDrive\\Documents\\ABISHEK\\PANDAS_PRACTICE\\Files\\Customer Call List.xlsx")
#       3 df2
#       4 import re
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
# ...

# %% [markdown]
# Splitting address in to different parts

# %%
df['Address']=df['Address'].fillna("")
df['Address']=df['Address'].str.replace("N/a","")
df[['Street_Address',"State","Zip_Code"]]=df["Address"].str.split(',',expand=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger          None
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN          None
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee          None
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger          None
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN          None
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee          None
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# ...

# %% [markdown]
# Replacing yes and No with relevant character

# %%
df[['Do_Not_Contact','Paying Customer']]=df[['Do_Not_Contact','Paying Customer']].replace("Yes","Y")
df[['Do_Not_Contact','Paying Customer']]=df[['Do_Not_Contact','Paying Customer']].replace("No","N")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger          None
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN          None
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee          None
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# ...

# %% [markdown]
# To fill Not a number with some values

# %%
df=df.fillna('')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# ...

# %%
df=df.replace('N/a','')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# ...

# %%
df = df[df["Do_Not_Contact"] != "Y"]
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 2         1003     Walter       White  706-695-0392
# 4         1005        Jon        Snow  876-678-3469
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# ...

# %%
df=df[df['Do_Not_Contact']!='']
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 4         1005        Jon        Snow  876-678-3469
# 7         1008   Sherlock      Holmes  876-678-3469
# 9         1010      Peter      Parker  123-545-5421
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 4                 123 Dragons Road               Y              N
# 7                    98 Clue Drive               N              N
# 9       25th Main Street, New York               Y              N
# ...

# %%
df=df[df['Phone_Number']!='']
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 4         1005        Jon        Snow  876-678-3469
# 7         1008   Sherlock      Holmes  876-678-3469
# 9         1010      Peter      Parker  123-545-5421
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 4                 123 Dragons Road               Y              N
# 7                    98 Clue Drive               N              N
# 9       25th Main Street, New York               Y              N
# ...

# %% [markdown]
# We can reset the index to look proper

# %%
df.reset_index()
# Out:
#    index  CustomerID First_Name   Last_Name  Phone_Number  \
# 0      0        1001      Frodo     Baggins  123-545-5421
# 1      4        1005        Jon        Snow  876-678-3469
# 2      7        1008   Sherlock      Holmes  876-678-3469
# 3      9        1010      Peter      Parker  123-545-5421
# 4     12        1013        Don      Draper  123-543-2345
# 5     13        1014     Leslie       Knope  876-678-3469
# 6     14        1015       Toby  Flenderson  304-762-2467
# 7     15        1016        Ron     Weasley  123-545-5421
# 8     16        1017   Michael        Scott  123-643-9775
# 9     19        1020     Anakin   Skywalker  876-678-3469
#
#                           Address Paying Customer Do_Not_Contact  \
# 0           123 Shire Lane, Shire               Y              N
# 1                123 Dragons Road               Y              N
# 2                   98 Clue Drive               N              N
# ...

# %%
df.reset_index(drop=True)
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number  \
# 0        1001      Frodo     Baggins  123-545-5421
# 1        1005        Jon        Snow  876-678-3469
# 2        1008   Sherlock      Holmes  876-678-3469
# 3        1010      Peter      Parker  123-545-5421
# 4        1013        Don      Draper  123-543-2345
# 5        1014     Leslie       Knope  876-678-3469
# 6        1015       Toby  Flenderson  304-762-2467
# 7        1016        Ron     Weasley  123-545-5421
# 8        1017   Michael        Scott  123-643-9775
# 9        1020     Anakin   Skywalker  876-678-3469
#
#                           Address Paying Customer Do_Not_Contact  \
# 0           123 Shire Lane, Shire               Y              N
# 1                123 Dragons Road               Y              N
# 2                   98 Clue Drive               N              N
# 3      25th Main Street, New York               Y              N
# 4                2039 Main Street               Y              N
# ...

# %% [markdown]
# drop=True removes the old index column

# %% [markdown]
# <h2>Now this data is cleaned properly</h2>
